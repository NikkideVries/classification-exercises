# %%
import warnings
warnings.filterwarnings("ignore")


#standard ds imports
import numpy as np
import pandas as pd

#stats and plotting
from pydataset import data
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from math import sqrt

import env
import os

# %% [markdown]
# ### Question 5. Use pydata to import the iris data. Create a pandas dataframe, df_iris, from this data.
# - print the first 3 rows
# - print the number of rows and columns (shape)
# - print the column names
# - print the data type of each column
# - print the summary statistics for each of the numeric variables

# %% [markdown]
# ##### a. print the first 3 rows

# %%
df_iris = sns.load_dataset('iris')
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ##### b. print the number of rows and columns (shape)

# %%
df_iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ##### c. print the column names

# %%
list(df_iris.columns)
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %% [markdown]
# ##### d. print the data type of each column

# %%
df_iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# ##### e. print the summary statistics for each of the numeric variables

# %%
df_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Question 6: Read the data from this google sheet into a dataframe, df_google.
# - print the first 3 rows
# - print the number of rows and columns
# - print the column names
# - print the data type of each column
# - print the summary statistics for each of the numeric variables
# - print the unique values for each of your categorical variables

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'
csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')
csv_export_url
# Out:
# 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/export?format=csv&gid=341089357'

# %%
df_google = pd.read_csv(csv_export_url)
df_google.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# #### a. print the first 3 rows

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# #### b. print the number of rows and columns:

# %%
df_google.shape
# Out:
# (891, 12)

# %% [markdown]
# #### c.print the column names.

# %%
list(df_google.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %% [markdown]
# #### d. print the data type of each column

# %%
df_google.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### e. print the summary statistics for each of the numeric variables

# %%
df_google.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %% [markdown]
# #### f. print the unique values for each of your categorical variables.

# %%
df_unique = df_google.select_dtypes(exclude=['int', 'float'])
for col in df_unique.columns:
    print(f'***{col} has {df_unique[col].unique()}') # to print categories name only
    print(df_unique[col].value_counts()) # to print count of every category
# Out:
# ***Name has ['Braund, Mr. Owen Harris'
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'
#  'Heikkinen, Miss. Laina' 'Futrelle, Mrs. Jacques Heath (Lily May Peel)'
#  'Allen, Mr. William Henry' 'Moran, Mr. James' 'McCarthy, Mr. Timothy J'
#  'Palsson, Master. Gosta Leonard'
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)'
#  'Nasser, Mrs. Nicholas (Adele Achem)' 'Sandstrom, Miss. Marguerite Rut'
#  'Bonnell, Miss. Elizabeth' 'Saundercock, Mr. William Henry'
#  'Andersson, Mr. Anders Johan' 'Vestrom, Miss. Hulda Amanda Adolfina'
#  'Hewlett, Mrs. (Mary D Kingcome) ' 'Rice, Master. Eugene'
#  'Williams, Mr. Charles Eugene'
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)'
#  'Masselmani, Mrs. Fatima' 'Fynney, Mr. Joseph J' 'Beesley, Mr. Lawrence'
#  'McGowan, Miss. Anna "Annie"' 'Sloper, Mr. William Thompson'
#  'Palsson, Miss. Torborg Danira'
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)'
# ...

# %%
# Count all of the unique values for dtype='object'

for col in df_google.columns.to_list():
    if df_google[col].dtypes == 'object':
        print(f'{col} has {df_google[col].nunique()} unique values.')
# Out:
# Name has 891 unique values.
# Sex has 2 unique values.
# Ticket has 681 unique values.
# Cabin has 147 unique values.
# Embarked has 3 unique values.

# %%
# we have a few more questionable columns to look at:

df_google.Survived.value_counts(dropna=False)
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df_google.Pclass.value_counts(dropna=False)
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df_google.Sex.value_counts(dropna=False)
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df_google.Embarked.value_counts(dropna=False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %% [markdown]
# ### Question 7. Download the google sheet from Exercise 6 into an .xslx (File → Download → Microsoft Excel). Read the downloaded file into a dataframe named df_excel.assign the first 100 rows to a new dataframe, df_excel_sample
# - assign the first 100 rows to a new dataframe, df_excel_sample
# - print the number of rows of your original dataframe
# - print the first 5 column names
# - print the column names that have a data type of object
# - compute the range for each of the numeric variables.

# %%
df_excel = pd.read_excel("train.xlsx", sheet_name = "train")

# %% [markdown]
# #### a. assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel_sample = df_excel.head(100)
#df_excel_sample

# %% [markdown]
# #### b. print the number of rows of your original dataframe

# %%
len(df_excel.index)
# Out:
# 891

# %%
df_excel.shape[1]
# Out:
# 12

# %% [markdown]
# #### c. print the first 5 column names

# %%
# one method
# df.iloc[row_start:row_end , col_start, col_end]
df_excel.iloc[:,:5]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex
# 0                                Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female
# 2                                 Heikkinen, Miss. Laina  female
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                               Allen, Mr. William Henry    male
# ..                                                   ...     ...
# 886                                Montvila, Rev. Juozas    male
# ...

# %%
# another method
df_excel.columns[:5]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'], dtype='object')

# %% [markdown]
# #### d. print the column names that have a data type of object

# %%
list(df_excel.select_dtypes(['object']).columns)
# Out:
# ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %% [markdown]
# #### e. compute the range for each of the numeric variables.

# %%
# need to get the numeric columns
numeric_columns = df_excel.select_dtypes(include=['int','float']).columns
for col in numeric_columns:
    min_num = df_excel[col].min()
    max_num = df_excel[col].max()
    col_range = max_num - min_num
    print(f'Range for {col}: {col_range}')
# Out:
# Range for PassengerId: 890
# Range for Survived: 1
# Range for Pclass: 2
# Range for Age: 79.58
# Range for SibSp: 8
# Range for Parch: 6
# Range for Fare: 512.3292

# %%
df_excel[['Age', 'Fare']].describe().T
# Out:
#       count       mean        std   min      25%      50%   75%       max
# Age   714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# Fare  891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
# the 2 cols i want to know the range on are age and fare
# I can select jus the true numeric variables to declutter my results

titanic_stats = df_excel[['Age', 'Fare']].describe().T
titanic_stats
# Out:
#       count       mean        std   min      25%      50%   75%       max
# Age   714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# Fare  891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
titanic_stats['range'] = titanic_stats['max'] - titanic_stats['min']
titanic_stats
# Out:
#       count       mean        std   min      25%      50%   75%       max  \
# Age   714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# Fare  891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292
#
#          range
# Age    79.5800
# Fare  512.3292

# %%
titanic_stats['range']
# Out:
# Age      79.5800
# Fare    512.3292
# Name: range, dtype: float64

# %% [markdown]
# ---------------------------------------------------------

# %% [markdown]
# ## Make a new python module, acquire.py to hold the following data acquisition functions:

# %%
def get_db_url(db, user=env.user, host=env.host, password=env.password):
    '''
    This function uses my info from my env file to
    create a connection url to access the Codeup db.
    '''
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

# %% [markdown]
# #### Question 1:
# Make a function named get_titanic_data that returns the Titanic data from the codeup data science database as a pandas data frame. Obtain your data from the Codeup Data Science Database.

# %%
def new_titanic_data(sql_query):
    """
    This function will:
    - take in a sql_query
    - create a connection url
    - return a df of the given query from the databse  
    """
    # create the connection url:
    url = get_db_url('titanic_db')
    
    return pd.read_sql(sql_query, url)

# %%
new_titanic_data('select * from passengers')
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  deck  embark_town  alone
# ...

# %% [markdown]
# #### Question 2.
# Make a function named get_iris_data that returns the data from the iris_db on the codeup data science database as a pandas data frame. The returned data frame should include the actual name of the species in addition to the species_ids. Obtain your data from the Codeup Data Science Database.

# %%
def new_iris_data(sql_query):
    """
    This function will:
    - take in a sql_query
    - create a connection url
    - return a df of the given query from the databse  
    """
    # create the connection url:
    url = get_db_url('iris_db')
    
    return pd.read_sql(sql_query, url)

# %%
new_iris_data("""
                SELECT species_id,
                species_name,
                sepal_length,
                sepal_width,
                petal_length,
                petal_width
                FROM measurements
                JOIN species
                USING(species_id)
                """).head()
# Out:
#    species_id species_name  sepal_length  sepal_width  petal_length  \
# 0           1       setosa           5.1          3.5           1.4
# 1           1       setosa           4.9          3.0           1.4
# 2           1       setosa           4.7          3.2           1.3
# 3           1       setosa           4.6          3.1           1.5
# 4           1       setosa           5.0          3.6           1.4
#
#    petal_width
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2

# %% [markdown]
# #### Question 3.
# Make a function named get_telco_data that returns the data from the telco_churn database in SQL. In your SQL, be sure to join contract_types, internet_service_types, payment_types tables with the customers table, so that the resulting dataframe contains all the contract, payment, and internet service options. Obtain your data from the Codeup Data Science Database.

# %%
def new_telco_data(sql_query):
    """
    This function will:
    - take in a sql_query
    - create a connection url
    - return a df of the given query from the databse  
    """
    # create the connection url:
    url = get_db_url('telco_churn')
    return pd.read_sql(sql_query, url)

# %%
sql_query = ('''
SELECT 
	customer_id,
    contract_type,
    internet_service_type,
    payment_type

FROM
	customers
    LEFT JOIN contract_types
		USING (contract_type_id)
	LEFT JOIN  internet_service_types
		USING (internet_service_type_id)
	LEFT JOIN payment_types
		USING (payment_type_id);
''')
new_telco_data(sql_query)
# Out:
#      customer_id   contract_type internet_service_type      payment_type
# 0     0002-ORFBO        One year                   DSL      Mailed check
# 1     0003-MKNFE  Month-to-month                   DSL      Mailed check
# 2     0004-TLHLJ  Month-to-month           Fiber optic  Electronic check
# 3     0011-IGKFF  Month-to-month           Fiber optic  Electronic check
# 4     0013-EXCHZ  Month-to-month           Fiber optic      Mailed check
# ...          ...             ...                   ...               ...
# 7038  9987-LUTYD        One year                   DSL      Mailed check
# 7039  9992-RRAMN  Month-to-month           Fiber optic  Electronic check
# 7040  9992-UJOEL  Month-to-month                   DSL      Mailed check
# 7041  9993-LHIEB        Two year                   DSL      Mailed check
# 7042  9995-HOTOH        Two year                   DSL  Electronic check
#
# [7043 rows x 4 columns]

# %% [markdown]
# #### Question 4:
# Once you've got your get_titanic_data, get_iris_data, and get_telco_data functions written, now it's time to add caching to them. To do this, edit the beginning of the function to check for the local filename of telco.csv, titanic.csv, or iris.csv. If they exist, use the .csv file. If the file doesn't exist, then produce the SQL and pandas necessary to create a dataframe, then write the dataframe to a .csv file with the appropriate name.

# %%
def get_titanic_data(SQL_query, filename="titanic.csv"):
    """
    This function will:
    - Check loacal directory for csv file
        - return df if file exists
        - If csv doesn't exist:
            - create a df of the sql query
            - write the df to a csv file
    - output titanic df
    """
    
    directory = (f'{os.getcwd()}/')
    
    # checks if csv exists
    if os.path.exists(directory + filename):
        #if YES
        df = pd.read_csv(filename)
        return df
    #if NO
    else:
        #obtaning new data from sql
        df = new_titanic_data(SQL_query)
        
        #convert to a csv
        df.to_csv(filename)
        return df

# %%
get_titanic_data('select * from passengers')
# Out:
#      passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0               0         0       3    male  22.0      1      0   7.2500
# 1               1         1       1  female  38.0      1      0  71.2833
# 2               2         1       3  female  26.0      0      0   7.9250
# 3               3         1       1  female  35.0      1      0  53.1000
# 4               4         0       3    male  35.0      0      0   8.0500
# ..            ...       ...     ...     ...   ...    ...    ...      ...
# 886           886         0       2    male  27.0      0      0  13.0000
# 887           887         1       1  female  19.0      0      0  30.0000
# 888           888         0       3  female   NaN      1      2  23.4500
# 889           889         1       1    male  26.0      0      0  30.0000
# 890           890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class  deck  embark_town  alone
# ...

# %%
def get_iris_data(SQL_query, filename="iris_db.csv"):
    """
    This function will:
    - take in an SQL_query
    - Check loacal directory for csv file
        - return df if file exists
        - If csv doesn't exist:
            - create a df of the sql query
            - write the df to a csv file
    - output iris df
    """
    directory = (f'{os.getcwd()}/')
    
    # checks if csv exists
    if os.path.exists(directory + filename):
        #if YES
        df = pd.read_csv(filename)
        return df
    #if NO
    else:
        #obtaning new data from sql
        df = new_iris_data(SQL_query)
        
        #convert to a csv
        df.to_csv(filename)
        return df

# %%
get_iris_data("""
            SELECT 
                species_id,
                species_name,
                sepal_length,
                sepal_width,
                petal_length,
                petal_width
            FROM measurements
            JOIN species USING(species_id)            
""").head()
# Out:
#    species_id species_name  sepal_length  sepal_width  petal_length  \
# 0           1       setosa           5.1          3.5           1.4
# 1           1       setosa           4.9          3.0           1.4
# 2           1       setosa           4.7          3.2           1.3
# 3           1       setosa           4.6          3.1           1.5
# 4           1       setosa           5.0          3.6           1.4
#
#    petal_width
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2

# %%
def get_telco_data(SQL_query, filename="telco_churn.csv"):
    """
    This function will:
    - take in an SQL_query
    - Check loacal directory for csv file
        - return df if file exists
        - If csv doesn't exist:
            - create a df of the sql query
            - write the df to a csv file
    - output telcho churn df
    """
    directory = (f'{os.getcwd()}/')
    
    # checks if csv exists
    if os.path.exists(directory + filename):
        #if YES
        df = pd.read_csv(filename)
        return df
    #if NO
    else:
        #obtaning new data from sql
        df = new_telco_data(SQL_query)
        
        #convert to a csv
        df.to_csv(filename)
        return df

# %%
get_telco_data('''
SELECT 
	customer_id,
    contract_type,
    internet_service_type,
    payment_type

FROM
	customers
    LEFT JOIN contract_types
		USING (contract_type_id)
	LEFT JOIN  internet_service_types
		USING (internet_service_type_id)
	LEFT JOIN payment_types
		USING (payment_type_id)
''')
# Out:
#      customer_id   contract_type internet_service_type      payment_type
# 0     0002-ORFBO        One year                   DSL      Mailed check
# 1     0003-MKNFE  Month-to-month                   DSL      Mailed check
# 2     0004-TLHLJ  Month-to-month           Fiber optic  Electronic check
# 3     0011-IGKFF  Month-to-month           Fiber optic  Electronic check
# 4     0013-EXCHZ  Month-to-month           Fiber optic      Mailed check
# ...          ...             ...                   ...               ...
# 7038  9987-LUTYD        One year                   DSL      Mailed check
# 7039  9992-RRAMN  Month-to-month           Fiber optic  Electronic check
# 7040  9992-UJOEL  Month-to-month                   DSL      Mailed check
# 7041  9993-LHIEB        Two year                   DSL      Mailed check
# 7042  9995-HOTOH        Two year                   DSL  Electronic check
#
# [7043 rows x 4 columns]

# %%
import acquire as ac
